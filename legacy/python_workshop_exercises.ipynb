# %% [markdown]
# # Python Workshop - Hands-On Exercises
#
# **© Kerry Back, Rice University**
#
# Welcome! This notebook contains practice exercises to complement the workshop slides. Each exercise includes self-grading code to check your work. For harder problems, look for Gemini hints.

# %% [markdown]
# ## Part 1: Google Colab
#
# No exercises - focus on getting comfortable with the Colab interface and Gemini AI integration.

# %% [markdown]
# ## Part 2: Objects
#
# Practice working with Python's basic object types: strings, numbers, and booleans.

# %% [markdown]
# ### Exercise 1: String Upper

# %%
# Convert the string "python programming" to uppercase and 
# assign it to the variable result1.


assert result1 == "PYTHON PROGRAMMING", "The result should be the uppercase version of 'python programming'"
print("Correct! You converted the string to uppercase.")

# %% [markdown]
# ### Exercise 2: String Replace

# %%
# Replace all occurrences of "cat" with "dog" in the 
# string "the cat sat on the cat" and assign it to the variable result4.


assert result4 == "the dog sat on the dog", "The result should have all 'cat' replaced with 'dog'"
print("Correct! You replaced all occurrences of 'cat' with 'dog'.")

# %% [markdown]
# ## Part 3: Lists
#
# Practice list operations including concatenation, indexing, and slicing.

# %% [markdown]
# ### Exercise 1: List Concatenation

# %%
# Concatenate list1 and list2 and assign the result to the variable fruit_combo.

list1 = ["apple", "banana"]
list2 = ["cherry", "date", "elderberry"]


assert fruit_combo == ["apple", "banana", "cherry", "date", "elderberry"], "The result should be ['apple', 'banana', 'cherry', 'date', 'elderberry']"
print("Correct! You concatenated the fruit lists.")

# %% [markdown]
# ### Exercise 2: Negative Indexing

# %%
# Get the last element from my_list using negative indexing
# and assign it to the variable last_number.

my_list = [5, 10, 15, 20, 25]


assert last_number == 25, "The result should be 25 (the last element)"
print("Correct! You accessed the last element using negative indexing.")

# %% [markdown]
# ### Exercise 3: List Slicing

# %%
# Get the first three elements from my_list using slicing
# and assign the result to the variable first_three.

my_list = ["a", "b", "c", "d", "e", "f"]


assert first_three == ["a", "b", "c"], "The result should be ['a', 'b', 'c'] (first three elements)"
print("Correct! You used slicing to get the first three elements.")

# %% [markdown]
# ## Part 4: Dictionaries
#
# Practice creating and accessing dictionaries.

# %% [markdown]
# ### Exercise 1: Create Dictionary

# %%
# Create a dictionary with keys "name", "age", and "city" 
# with values "John", 25, and "New York" respectively.
# Assign it to the variable person_info.


assert person_info == {"name": "John", "age": 25, "city": "New York"}, "The result should be a dictionary with the specified key-value pairs"
print("Correct! You created a dictionary with person information.")

# %% [markdown]
# ### Exercise 2: Access Dictionary Value

# %%
# Access the "model" value from the dictionary {"brand": "Honda", "model": "Civic", "year": 2019}
# and assign it to the variable car_model.


assert car_model == "Civic", "The result should be 'Civic'"
print("Correct! You accessed the model value from the dictionary.")

# %% [markdown]
# ## Part 5: Flow Control
#
# Practice conditional statements, loops, and comprehensions.

# %% [markdown]
# ### Exercise 1: Ternary Operator (Compact If-Else)

# %%
# Use a compact if-else to find the absolute value of a number.
# Assign the result to the variable abs_value.
number = -15


assert abs_value == 15, "The absolute value of -15 should be 15"
print("Correct! You calculated absolute value using compact if-else.")

# %% [markdown]
# ### Exercise 2: For Loop Sum

# %%
# Use a for loop to calculate the sum of numbers from 1 to 10.
# Assign the result to the variable total_sum.


assert total_sum == 55, "The sum of numbers 1 to 10 should be 55"
print("Correct! You calculated the sum using a for loop.")

# %% [markdown]
# ### Exercise 3: While Loop

# %%
# Use a while loop to calculate 2^n where n is the first power that makes 2^n > 1000.
# Assign n to the variable power and 2^n to the variable result.


assert power == 10 and result == 1024, "2^10 = 1024 is the first power of 2 greater than 1000"
print("Correct! You found the first power of 2 greater than 1000.")

# %% [markdown]
# ### Exercise 4: List Comprehension

# %%
# Use a list comprehension to create a list of cubes for numbers 1 through 6.
# Assign the result to the variable cubes.


assert cubes == [1, 8, 27, 64, 125, 216], "The result should be cubes of numbers 1-6"
print("Correct! You created a list of cubes using list comprehension.")

# %% [markdown]
# ### Exercise 5: Dictionary Comprehension

# %%
# Use a dictionary comprehension to create a dictionary where keys are words 
# and values are their lengths for: ["cat", "dog", "elephant", "bird"].
# Assign the result to the variable word_lengths.


assert word_lengths == {"cat": 3, "dog": 3, "elephant": 8, "bird": 4}, "Dictionary should map words to their lengths"
print("Correct! You created a word length dictionary using dictionary comprehension.")

# %% [markdown]
# ## Part 6: Functions
#
# Practice creating custom functions with parameters and return values.

# %% [markdown]
# ### Exercise 1: Is Even Function

# %%
# Create a function named is_even that takes a number and returns True if it's even, False otherwise.
# Then test it with the number 12.


result = is_even(12)
assert result == True, "12 should be identified as even"
print("Correct! You created a function to check if numbers are even.")

# %% [markdown]
# ### Exercise 2: Circle Properties

# %%
# Create a function called 'circle_properties' that takes a radius and 
# returns both area and circumference.
# Use pi = 3.14159. Test it with radius = 4.


area, circumference = circle_properties(4)
assert abs(area - 50.26544) < 0.001 and abs(circumference - 25.13272) < 0.001, "Check your area and circumference calculations"
print("Correct! You created a function that returns multiple values.")

# %% [markdown]
# ### Exercise 3: Power Function with Default Parameter

# %%
# Create a function called 'power' that calculates x^y, with y defaulting to 2.
# Test it with power(5) and power(3, 4).


result1 = power(5)      # Should be 5^2 = 25
result2 = power(3, 4)   # Should be 3^4 = 81
assert result1 == 25 and result2 == 81, "Check your power function implementation"
print("Correct! You created a function with default parameters.")

# %% [markdown]
# ## Part 7: Libraries
#
# No exercises - focus on understanding import statements and standard conventions.

# %% [markdown]
# ## Part 8: Pandas Introduction
#
# Practice creating DataFrames, working with Series, and basic data manipulation.

# %% [markdown]
# ### Exercise 1: Create a DataFrame

# %%
import pandas as pd

# Create a DataFrame with student information using a dictionary.
# Include columns: 'Student', 'Math', 'Science', 'English' with data for 3 students.


assert len(students_df) == 3, "Should have 3 students"
assert list(students_df.columns) == ['Student', 'Math', 'Science', 'English'], "Should have correct column names"
print("Correct! You created a DataFrame with student information.")

# %% [markdown]
# ### Exercise 2: Series Indexing Practice

# %%
# Practice: Using the prices Series, complete these exercises.
# Create the Series first
import pandas as pd

prices = pd.Series([29.99, 999.99, 79.99, 299.99, 149.99, 399.99], 
                   index=['Mouse', 'Laptop', 'Keyboard', 'Monitor', 'Headset', 'Tablet'])

# Exercise 2a: Get the price of the 'Headset' using label indexing
# Assign to 'headset_price'


# Exercise 2b: Get the first 3 items using .iloc (position-based)
# Assign to 'first_three'


# Exercise 2c: Get the last 2 items using .iloc
# Assign to 'last_two'


# Exercise 2d: Get every other item starting from the first using .iloc
# Assign to 'every_other'


assert headset_price == 149.99, "Should get Headset price using label indexing"
assert len(first_three) == 3 and first_three.iloc[0] == 29.99, "Should get first 3 items using .iloc"
assert len(last_two) == 2 and last_two.iloc[-1] == 399.99, "Should get last 2 items using .iloc"
assert len(every_other) == 3, "Should get every other item using .iloc[::2]"
print("Excellent! You've mastered Series indexing and slicing!")

# %% [markdown]
# ### Exercise 3: Select Specific Columns

# %%
# Create sample data first
employees = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Eve', 'Frank'],
    'Age': [25, 30, 35, 28, 32, 45],
    'Department': ['Engineering', 'Marketing', 'Engineering', 'HR', 'Marketing', 'Engineering'],
    'Salary': [70000, 65000, 80000, 60000, 72000, 90000],
    'Years': [2, 5, 8, 3, 6, 12]
})

# Select only the 'Name' and 'Department' columns from the employees DataFrame.
# Assign the result to 'name_dept'.


assert list(name_dept.columns) == ['Name', 'Department'], "Should only have Name and Department columns"
assert len(name_dept) == 6, "Should have all 6 employees"
print("Correct! You selected specific columns.")

# %% [markdown]
# ### Exercise 4: Add Calculated Column

# %%
# Using the employees DataFrame, add a new column 'Total_Compensation' 
# that equals Salary + (Salary * 0.15). Assign the modified DataFrame to 'emp_with_total'.


assert 'Total_Compensation' in emp_with_total.columns, "Should have Total_Compensation column"
assert emp_with_total.loc[0, 'Total_Compensation'] == 70000 * 1.15, "Should calculate total compensation correctly"
print("Correct! You added a calculated column.")

# %% [markdown]
# ## Part 9: More Pandas
#
# Practice advanced pandas operations: grouping, merging, and pivot tables.

# %% [markdown]
# ### Exercise 1: Comprehensive Tips Dataset Analysis
#
# **💡 Gemini Hint:** For this exercise, you can ask Gemini: "How do I create a new column in pandas that calculates a percentage?" or "How do I create a pivot table with margins in pandas?"

# %%
# Load the tips dataset
import seaborn as sns
import numpy as np

tips = sns.load_dataset('tips')

# Task 1: Data Exploration
# Create a new column 'tip_percentage' that calculates tip as a percentage of total_bill
# Assign the modified DataFrame to 'tips_with_pct'


# Task 2: Grouping and Aggregation
# Calculate the average tip percentage by day of the week
# Assign the result to 'avg_tip_by_day'


# Task 3: Advanced Grouping
# Create a summary table showing average total_bill, average tip, and count of customers
# grouped by both 'time' (Lunch/Dinner) and 'smoker' (Yes/No)
# Assign the result to 'time_smoker_summary'


# Task 4: Data Filtering
# Find all the generous tippers (tip_percentage > 20%)
# Assign the filtered DataFrame to 'generous_tippers'


# Task 5: Pivot Table
# Create a pivot table showing average tip amount by day (rows) and time (columns)
# Include margins to show totals
# Assign the result to 'tip_pivot'


# Task 6: String Processing
# Add a new column 'day_type' that categorizes days as:
# - 'Weekend' for Sat and Sun
# - 'Weekday' for Thur and Fri
# Use the .str methods or .map()
# Assign the modified DataFrame to 'tips_categorized'


# Task 7: Merging Practice
# Create a small DataFrame with average meal prices by day
meal_prices = pd.DataFrame({
    'day': ['Thur', 'Fri', 'Sat', 'Sun'],
    'avg_meal_price': [25, 30, 35, 32]
})
# Merge this with tips_categorized to add the avg_meal_price column
# Assign the result to 'tips_with_prices'


# Task 8: Data Cleaning
# Create a copy of tips and randomly set 10 values to NaN in the 'tip' column
# Then fill these missing values with the median tip amount
# Assign the cleaned DataFrame to 'tips_cleaned'
tips_missing = tips.copy()
np.random.seed(42)
missing_indices = np.random.choice(tips_missing.index, size=10, replace=False)
tips_missing.loc[missing_indices, 'tip'] = np.nan
# Now fill the missing values


# Assertions to check your work
assert 'tip_percentage' in tips_with_pct.columns, "Should have tip_percentage column"
assert round(tips_with_pct['tip_percentage'].mean(), 2) == 16.08, "Average tip percentage should be about 16.08%"

assert len(avg_tip_by_day) == 4, "Should have 4 days"
assert avg_tip_by_day.loc['Sun'] > 15, "Sunday average tip percentage should be > 15%"

assert time_smoker_summary.shape == (4, 3), "Summary should be 4x3 (4 groups, 3 metrics)"

assert len(generous_tippers) > 30, "Should find at least 30 generous tippers"
assert all(generous_tippers['tip_percentage'] > 20), "All generous tippers should have > 20% tip"

assert 'Total' in tip_pivot.columns, "Pivot table should include margins (Total column)"

assert 'day_type' in tips_categorized.columns, "Should have day_type column"
assert set(tips_categorized['day_type'].unique()) == {'Weekend', 'Weekday'}, "Should have Weekend and Weekday categories"

assert 'avg_meal_price' in tips_with_prices.columns, "Should have avg_meal_price after merge"
assert len(tips_with_prices) == len(tips), "Should maintain all rows after merge"

assert tips_cleaned['tip'].isna().sum() == 0, "Should have no missing values after cleaning"
assert len(tips_cleaned) == len(tips), "Should maintain same number of rows"

print("🎉 Excellent work! You've successfully completed all the exercises!")
print("\nKey insights from your analysis:")
print(f"• Average tip percentage: {tips_with_pct['tip_percentage'].mean():.1f}%")
print(f"• Most generous day: {avg_tip_by_day.idxmax()} ({avg_tip_by_day.max():.1f}%)")
print(f"• Number of generous tippers (>20%): {len(generous_tippers)}")
print(f"• Weekend vs Weekday distribution: {tips_categorized['day_type'].value_counts().to_dict()}")

# %% [markdown]
# ## Part 10: Visualization Introduction
#
# Practice creating visualizations using matplotlib. For these exercises, use Gemini to help create and customize plots.

# %% [markdown]
# ### Exercise 1: Create Custom Visualizations
#
# **Instructions:** Use the wages dataset below. Ask Gemini to help you create the following plots:
#
# 1. A bar plot showing the relationship of wage to education_level
# 2. Box plots showing the relationship of wage to education_level
# 3. A scatter plot showing the relationship of wage to educ
# 4. A figure with two subplots: the bar plot and the scatter plot
#
# For each plot, experiment with customization (title, axis labels, font sizes, colors, and style).
#
# **💡 Gemini Hints:**
# - "Create a bar plot in matplotlib showing average wage by education level"
# - "How do I customize plot colors and font sizes in matplotlib?"
# - "Create a figure with 2 subplots in matplotlib"

# %%
# Load and prepare the wages dataset
import pandas as pd
import matplotlib.pyplot as plt

url = 'https://faculty.utrgv.edu/diego.escobari/teaching/Datasets/WAGE1.xls'
wages = pd.read_excel(url, header=None)

columns = [
    'wage', 'educ', 'exper',
    'tenure', 'nonwhite', 'female',
    'married', 'numdep',
    'smsa', 'northcen',
    'south', 'west', 'construc',
    'ndurman', 'trcommpu', 'trade',
    'services', 'profserv',
    'profocc', 'clerocc', 'servocc',
    'lwage', 'expersq', 'tenursq'
]
wages.columns = columns

# Convert to categorical variables
wages['Gender'] = wages['female'].map({0: 'Male', 1: 'Female'})
wages['Race'] = wages['nonwhite'].map({0: 'White', 1: 'Non-white'})
wages['Marital_Status'] = wages['married'].map({0: 'Not Married', 1: 'Married'})
wages['Urban'] = wages['smsa'].map({0: 'Rural', 1: 'Urban'})

def get_region(row):
    if row['northcen'] == 1:
        return 'North Central'
    elif row['south'] == 1:
        return 'South'
    elif row['west'] == 1:
        return 'West'
    else:
        return 'Northeast'

wages['Region'] = wages.apply(get_region, axis=1)

def get_industry(row):
    if row['construc'] == 1:
        return 'Construction'
    elif row['ndurman'] == 1:
        return 'Non-durable Manufacturing'
    elif row['trcommpu'] == 1:
        return 'Transportation/Communications'
    elif row['trade'] == 1:
        return 'Trade'
    elif row['services'] == 1:
        return 'Services'
    elif row['profserv'] == 1:
        return 'Professional Services'
    else:
        return 'Other'

wages['Industry'] = wages.apply(get_industry, axis=1)

def get_occupation(row):
    if row['profocc'] == 1:
        return 'Professional'
    elif row['clerocc'] == 1:
        return 'Clerical'
    elif row['servocc'] == 1:
        return 'Service'
    else:
        return 'Other'

wages['Occupation'] = wages.apply(get_occupation, axis=1)

# Create education categories
wages['Education_Level'] = pd.cut(wages['educ'], 
                                 bins=[0, 12, 16, 25], 
                                 labels=['High School or Less', 'Some College', 'College Plus'])

# Create experience categories  
wages['Experience_Level'] = pd.cut(wages['exper'], 
                                  bins=[0, 5, 15, 60], 
                                  labels=['Low (0-5)', 'Mid (6-15)', 'High (16+)'])

# Delete columns we do not need
wages = wages.drop(columns=wages.columns[4:-9])

print("Wages dataset is ready for visualization!")
print(f"Shape: {wages.shape}")
print("\nFirst few rows:")
print(wages.head())

# Now create your visualizations here using Gemini's help
# Ask Gemini to create:
# 1. Bar plot of wage vs education_level
# 2. Box plot of wage vs education_level
# 3. Scatter plot of wage vs educ
# 4. Figure with 2 subplots combining bar and scatter plots

# %% [markdown]
# ## Part 11: More Visualization
#
# No formal exercises - explore seaborn statistical plots using the examples from the slides.

# %% [markdown]
# ## Part 12: Plotly
#
# No formal exercises - explore interactive plotly visualizations using the examples from the slides.

# %% [markdown]
# ## Part 13: Simulation
#
# Practice creating simulations using numpy random number generation.

# %% [markdown]
# ### Exercise 1: Simulate Coin Flips

# %%
import numpy as np

# Simulate coin flips
# Flip a coin 100 times and count heads vs tails
# Create a variable 'coin_flips' with the results (1 = heads, 0 = tails)


# Check your work
num_heads = np.sum(coin_flips)
num_tails = len(coin_flips) - num_heads
print(f"Results: {num_heads} heads, {num_tails} tails")
print(f"Percentage heads: {num_heads/len(coin_flips)*100:.1f}%")
assert len(coin_flips) == 100, "Should have 100 flips"
assert all(flip in [0, 1] for flip in coin_flips), "Flips should be 0 or 1"
print("Great job! You simulated coin flips.")

# %% [markdown]
# ### Exercise 2: Retirement Planning Simulation
#
# **💡 Gemini Hint:** This is a complex multi-part exercise. You can ask Gemini: "Help me create a function that simulates retirement savings with two phases: accumulation and withdrawal" or "How do I simulate investment returns with volatility in Python?"

# %%
# Scenario: Complete lifetime financial planning
# Phase 1 - ACCUMULATION: Save for retirement while working
# Phase 2 - RETIREMENT: Withdraw funds for living expenses
# 
# Assumptions:
# - Starting savings: $50,000
# - Annual contribution during working years: $25,000
# - Working period: 30 years
# - Annual withdrawal in retirement: $100,000 (adjusted for inflation)
# - Retirement period: 25 years
# - Investment returns vary each year (historical average ~7%, but with volatility)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Set seed for reproducibility
np.random.seed(42)

# Initial parameters
initial_savings = 50000
annual_contribution = 25000
working_years = 30
retirement_years = 25
base_withdrawal = 100000

# Return parameters
avg_return = 0.07
return_volatility = 0.15

# PART A: Create a function that simulates one lifetime
# The function should contain two loops:
# 1. Loop over working years (add contributions, apply returns)
# 2. Loop over retirement years (subtract withdrawals, apply returns)
# Return the balance at the end of retirement


# PART B: Run the function 1,000 times
# Compile a list of ending balances from all simulations


# PART C: Analyze the results
# Calculate mean, median, standard deviation, and percentiles (10%, 25%, 50%, 75%, 90%)
# Create a histogram of ending balances
# Hint: Convert to a pandas Series for easy statistics: ser = pd.Series(ending_balances)
# Then use ser.mean(), ser.median(), ser.std(), ser.quantile(0.1), etc.


print("Retirement simulation complete!")

# %% [markdown]
# ## Part 14: Goal Seek
#
# Practice using scipy.optimize.fsolve and minimize for solving equations and optimization problems.

# %% [markdown]
# ### Exercise 1: Solve Cubic Equation
#
# **💡 Gemini Hint:** Ask Gemini: "How do I use fsolve to find multiple solutions to an equation?"

# %%
from scipy.optimize import fsolve

# Problem: Find the values of x where x³ - 6x² = 6 - 11x
# Rearrange to: x³ - 6x² + 11x - 6 = 0

# Hints:
# - This equation has three solutions
# - Try different starting guesses to find all three solutions
# - Remember to define a function that equals zero at the solution

# Step 1: Define the function


# Step 2: Find solutions using different initial guesses


# Step 3: Verify your answers


print("Exercise complete! You found the solutions to the cubic equation.")

# %% [markdown]
# ### Exercise 2: Maximize Profit
#
# **💡 Gemini Hint:** Ask Gemini: "How do I use scipy minimize to maximize a profit function?"

# %%
from scipy.optimize import minimize

# Scenario: A monopolist wants to choose the optimal output level to maximize profit.
#
# Problem Setup:
# - Demand curve: P = 100 - 2Q (price decreases as quantity increases)
# - Variable cost: $20 per unit (constant)
# - Fixed cost: $500
# - Revenue: R(Q) = P × Q = (100 - 2Q) × Q = 100Q - 2Q²
# - Total Cost: TC(Q) = 500 + 20Q
# - Profit: π(Q) = R(Q) - TC(Q) = 100Q - 2Q² - 500 - 20Q = 80Q - 2Q² - 500
# - Goal: Find the quantity Q that maximizes profit

# Remember: To maximize, minimize the negative!

# Step 1: Define the profit function (as negative for minimization)


# Step 2: Use minimize to find optimal quantity


# Step 3: Report results (optimal quantity and maximum profit)


print("Exercise complete! You found the profit-maximizing quantity.")

# %% [markdown]
# ### Exercise 3: Marketing Budget Allocation
#
# **💡 Gemini Hint:** Ask Gemini: "How do I use scipy minimize with constraints and bounds for budget allocation?"

# %%
import numpy as np
from scipy.optimize import minimize

# Scenario: You have a $100,000 marketing budget to allocate across three channels.
# Each channel has different returns and constraints.
#
# Channel Data:
# - Digital: $3 return per $1 spent, minimum $10,000, maximum $60,000
# - TV: $2.5 return per $1 spent, minimum $20,000, maximum $50,000
# - Print: $2 return per $1 spent, minimum $5,000, maximum $30,000
#
# Goal: Maximize total return while spending no more than $100,000

# Define the returns per dollar for each channel
returns = np.array([3, 2.5, 2])  # Digital, TV, Print

# Total budget
total_budget = 100000

# Step 1: Define the function to minimize (negative total return)


# Step 2: Define bounds for each channel (min, max)


# Step 3: Define constraint (total spending <= budget)


# Step 4: Set initial guess


# Step 5: Run minimize


# Step 6: Report results


print("Exercise complete! You optimized the marketing budget allocation.")

# %% [markdown]
# ## Part 15: Neural Networks
#
# No formal exercises - explore the neural network concepts from the slides. The topic is introduced conceptually without requiring implementation exercises.

# %% [markdown]
# ---
#
# ## Congratulations!
#
# You've completed all the Python workshop exercises. You've practiced:
#
# - ✅ **Basic Python objects** - strings, numbers, booleans
# - ✅ **Data structures** - lists and dictionaries
# - ✅ **Flow control** - conditionals, loops, comprehensions
# - ✅ **Functions** - creating custom functions with parameters
# - ✅ **Pandas fundamentals** - DataFrames, Series, filtering, grouping
# - ✅ **Advanced pandas** - merging, pivot tables, string processing
# - ✅ **Visualization** - matplotlib customization
# - ✅ **Simulation** - random number generation, Monte Carlo
# - ✅ **Optimization** - fsolve and minimize
#
# Keep practicing and exploring! Use Gemini to help you tackle new challenges.
